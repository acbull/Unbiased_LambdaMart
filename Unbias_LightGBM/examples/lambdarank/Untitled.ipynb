# %%
import lightgbm as lgb
from sklearn.datasets import load_svmlight_file

# %%
X_train, y_train = load_svmlight_file('rank.train')
group = [int(gi) for gi in open('rank.train.query').readlines()]
ps = []
for g in group:
    ps += list(range(g))
# fo = open('./rank.train.rank', 'w')
# for i in ps:
#     fo.write(str(i) + '\n')
# fo.close()

# %%
ranker = lgb.LGBMRanker()

# %%
ranker.fit(X_train, y_train, group = group, rank = ps)
# Out:
# lambdarank False
# None
# 0
# 2 2
# 2
# 2 2
# 2
# 2 2
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-4-b1d9240b2db4> in <module>
# ----> 1 ranker.fit(X_train, y_train, group = group, rank = ps)
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, rank, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_group, eval_rank, eval_metric, eval_at, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     796                                     verbose=verbose, feature_name=feature_name,
#     797                                     categorical_feature=categorical_feature,
# --> 798                                     callbacks=callbacks)
#     799         return self
#     800
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, rank, eval_rank, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     473                               verbose_eval=verbose, feature_name=feature_name,
#     474                               categorical_feature=categorical_feature,
# --> 475                               callbacks=callbacks)
#     476
#     477         if evals_result:
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     180     # construct booster
#     181     try:
# --> 182         booster = Booster(params=params, train_set=train_set)
#     183         if is_valid_contain_train:
#     184             booster.set_train_data_name(train_data_name)
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1321             self.handle = ctypes.c_void_p()
#    1322             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1323                 train_set.construct().handle,
#    1324                 c_str(params_str),
#    1325                 ctypes.byref(self.handle)))
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in construct(self)
#     859                                 weight=self.weight, group=self.group, rank = self.rank, init_score=self.init_score,
#     860                                 predictor=self._predictor, silent=self.silent, feature_name=self.feature_name,
# --> 861                                 categorical_feature=self.categorical_feature, params=self.params)
#     862             if self.free_raw_data:
#     863                 self.data = None
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, rank, init_score, predictor, silent, feature_name, categorical_feature, params)
#     727             self.set_group(group)
#     728         if rank is not None:
# --> 729             self.set_rank(rank)
#     730         # load init score
#     731         if init_score is not None:
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in set_rank(self, rank)
#    1159         if self.handle is not None and rank is not None:
#    1160             rank = list_to_1d_numpy(rank, np.int32, name='rank')
# -> 1161             self.set_field('rank', rank)
#    1162
#    1163
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in set_field(self, field_name, data)
#     987             ptr_data,
#     988             ctypes.c_int(len(data)),
# --> 989             ctypes.c_int(type_data)))
#     990
#     991     def get_field(self, field_name):
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py in _safe_call(ret)
#      47     """
#      48     if ret != 0:
# ---> 49         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      50
#      51
#
# LightGBMError: Input data type error or field not found
